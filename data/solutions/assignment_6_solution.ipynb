# %% [markdown]
# # Assignment 6 Solution - Expected Outputs

# %%
# Expected data dimensions
# Out:
# Dataset Dimensions:
# Customers: 100 rows x 5 columns
# Orders: 250 rows x 4 columns
# Order Items: 400 rows x 4 columns
# Products: 50 rows x 4 columns
# Suppliers: 10 rows x 3 columns

# %%
# Part 2.1: Inner Join
# Out:
# Inner Join Results: Customers: 100  Orders: 250  Inner Join Result: 200

# %%
# Part 2.2: Left Join
# Out:
# Left Join Results: Total rows: 200  Customers without orders: 0

# %%
# Part 2.3: Right Join
# Out:
# Right Join Results: Total rows: 250  Orders with invalid customer IDs: 50

# %%
# Part 2.4: Full Join
# Out:
# Full Join Results: Total rows: 250  Customers without orders: 0  Orders without valid customers: 50

# %%
# Part 3.1: orders_items
# Out:
# Step 1 - Orders with Items: 400 rows

# %%
# Part 3.2: orders_customers_items
# Out:
# Step 2 - Add Customers: 310 rows

# %%
# Part 3.3: complete_order_data
# Out:
# Step 3 - Add Products: 310 rows

# %%
# Part 3.4: complete_data
# Out:
# Step 4 - Complete Supply Chain: 310 rows

# %%
# Part 4.1: customers_no_orders
# Out:
# Customers who never placed an order: 0

# %%
# Part 4.2: orphaned_orders
# Out:
# Orders without corresponding customers: 50

# %%
# Part 4.3: products_never_ordered
# Out:
# Products that were never ordered: 0

# %%
# Part 4.4: active_customers
# Out:
# Customers who placed at least one order: 100

# %%
# Part 5.1: customer_metrics
# Out:
# Customer Analysis Summary: Total customers analyzed: 94  Top customer total spent: $ 8471.51

# %%
# Part 5.2: product_metrics
# Out:
# Product Analysis Summary: Total products analyzed: 50  Top product revenue: $ 11763.16

# %%
# Part 5.3: supplier_metrics
# Out:
# Supplier Analysis Summary: Total suppliers analyzed: 10  Max products per supplier: 10

# %%
# Part 5.4: regional_analysis
# Out:
# Regional Analysis Summary: Total cities analyzed: 5  Highest city sales: $ 72277.52

# %%
# Part 6.1: top_customers
# Out:
# Customer Segmentation Results:
# Top 10% spending threshold: $ 4931.51
# Number of top customers: 10
